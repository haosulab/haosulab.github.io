# %% [markdown]
# <a href="https://colab.research.google.com/github/haosulab/haosulab.github.io/blob/master/ml-for-robotics/hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Code
#
# To begin, prepare the colab environment by clicking the play button below. This will install all dependencies for the future code and should take no more than 2 minutes. Make sure to also click `Runtime` on the top tab, then `Change Runtime Type` and make sure you are using a GPU runtime. The free tier of Google Colab will be sufficient but if you have access to a GPU we recommend you to download this notebook (File -> Download -> Download.ipynb) as Colab's resources are limited.

# %%
# !apt-get install -y --no-install-recommends libvulkan-dev
# !pip install "setuptools>=62.3.0" pyglet
# !pip install -v git+https://github.com/haosulab/ManiSkill2.git@tutorials
# !pip uninstall -y pathlib  # avoid overriding the builtin one

# !pip install sapien gym==0.21.0 pyyaml tabulate tqdm h5py transforms3d opencv-python imageio imageio[ffmpeg] trimesh open3d rtree GitPython
# !pip uninstall -y sapien && pip install https://anaconda.org/jigu/sapien/2.0.0.dev20230112/download/sapien-2.0.0.dev20230112-cp38-cp38-manylinux2014_x86_64.whl
# !cd ManiSkill2 && python setup.py develop
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libvulkan-dev is already the newest version (1.2.131.2-1).
# libvulkan-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools>=62.3.0
#   Downloading setuptools-66.1.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.7 MB/s eta 0:00:00
# Collecting pyglet
#   Downloading pyglet-2.0.3-py3-none-any.whl (968 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 968.6/968.6 KB 57.8 MB/s eta 0:00:00
# Installing collected packages: pyglet, setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 66.1.1 which is incompatible.
# Successfully installed pyglet-2.0.3 setuptools-66.1.1
# Using pip 22.0.4 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/haosulab/ManiSkill2.git@tutorials
#   Cloning https://github.com/haosulab/ManiSkill2.git (to revision tutorials) to /tmp/pip-req-build-3k7j28nb
#   Running command git version
#   git version 2.25.1
#   Running command git clone --filter=blob:none https://github.com/haosulab/ManiSkill2.git /tmp/pip-req-build-3k7j28nb
#   Cloning into '/tmp/pip-req-build-3k7j28nb'...
#   Updating files:   0% (2/342)
#   Updating files:   1% (4/342)
#   Updating files:   2% (7/342)
#   Updating files:   3% (11/342)
#   Updating files:   4% (14/342)
#   Updating files:   5% (18/342)
#   Updating files:   6% (21/342)
#   Updating files:   7% (24/342)
#   Updating files:   8% (28/342)
#   Updating files:   9% (31/342)
#   Updating files:  10% (35/342)
#   Updating files:  11% (38/342)
#   Updating files:  12% (42/342)
#   Updating files:  13% (45/342)
#   Updating files:  14% (48/342)
#   Updating files:  15% (52/342)
#   Updating files:  16% (55/342)
#   Updating files:  17% (59/342)
#   Updating files:  18% (62/342)
#   Updating files:  19% (65/342)
#   Updating files:  20% (69/342)
#   Updating files:  21% (72/342)
#   Updating files:  22% (76/342)
#   Updating files:  23% (79/342)
#   Updating files:  24% (83/342)
#   Updating files:  25% (86/342)
#   Updating files:  26% (89/342)
#   Updating files:  27% (93/342)
#   Updating files:  28% (96/342)
#   Updating files:  29% (100/342)
#   Updating files:  30% (103/342)
#   Updating files:  31% (107/342)
#   Updating files:  32% (110/342)
#   Updating files:  33% (113/342)
#   Updating files:  34% (117/342)
#   Updating files:  35% (120/342)
#   Updating files:  36% (124/342)
#   Updating files:  37% (127/342)
#   Updating files:  38% (130/342)
#   Updating files:  39% (134/342)
#   Updating files:  40% (137/342)
#   Updating files:  41% (141/342)
#   Updating files:  42% (144/342)
#   Updating files:  43% (148/342)
#   Updating files:  44% (151/342)
#   Updating files:  45% (154/342)
#   Updating files:  46% (158/342)
#   Updating files:  47% (161/342)
#   Updating files:  48% (165/342)
#   Updating files:  49% (168/342)
#   Updating files:  50% (171/342)
#   Updating files:  51% (175/342)
#   Updating files:  52% (178/342)
#   Updating files:  53% (182/342)
#   Updating files:  54% (185/342)
#   Updating files:  55% (189/342)
#   Updating files:  56% (192/342)
#   Updating files:  57% (195/342)
#   Updating files:  58% (199/342)
#   Updating files:  59% (202/342)
#   Updating files:  60% (206/342)
#   Updating files:  61% (209/342)
#   Updating files:  62% (213/342)
#   Updating files:  63% (216/342)
#   Updating files:  64% (219/342)
#   Updating files:  65% (223/342)
#   Updating files:  66% (226/342)
#   Updating files:  67% (230/342)
#   Updating files:  68% (233/342)
#   Updating files:  69% (236/342)
#   Updating files:  70% (240/342)
#   Updating files:  71% (243/342)
#   Updating files:  72% (247/342)
#   Updating files:  73% (250/342)
#   Updating files:  74% (254/342)
#   Updating files:  75% (257/342)
#   Updating files:  76% (260/342)
#   Updating files:  77% (264/342)
#   Updating files:  78% (267/342)
#   Updating files:  79% (271/342)
#   Updating files:  80% (274/342)
#   Updating files:  81% (278/342)
#   Updating files:  82% (281/342)
#   Updating files:  83% (284/342)
#   Updating files:  84% (288/342)
#   Updating files:  85% (291/342)
#   Updating files:  86% (295/342)
#   Updating files:  87% (298/342)
#   Updating files:  88% (301/342)
#   Updating files:  89% (305/342)
#   Updating files:  90% (308/342)
#   Updating files:  91% (312/342)
#   Updating files:  92% (315/342)
#   Updating files:  93% (319/342)
#   Updating files:  94% (322/342)
#   Updating files:  95% (325/342)
#   Updating files:  96% (329/342)
#   Updating files:  97% (332/342)
#   Updating files:  98% (336/342)
#   Updating files:  99% (339/342)
#   Updating files: 100% (342/342)
#   Updating files: 100% (342/342), done.
#   Running command git show-ref tutorials
#   f217f9ae920bafbf3d17f800141db0eaba0251c6 refs/remotes/origin/tutorials
#   Running command git symbolic-ref -q HEAD
#   refs/heads/main
#   Running command git checkout -b tutorials --track origin/tutorials
#   Switched to a new branch 'tutorials'
#   Branch 'tutorials' set up to track remote branch 'tutorials' from 'origin'.
#   Resolved https://github.com/haosulab/ManiSkill2.git to commit f217f9ae920bafbf3d17f800141db0eaba0251c6
#   Running command pip subprocess to install build dependencies
#   Using pip 22.0.4 from /tmp/pip-standalone-pip-r5nvzpya/__env_pip__.zip/pip (python 3.8)
#   Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://us-python.pkg.dev/colab-wheels/public/simple/
#   Collecting setuptools>=62.3.0
#     Using cached setuptools-66.1.1-py3-none-any.whl (1.3 MB)
#   Installing collected packages: setuptools
#   ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
#   ipython 7.9.0 requires jedi>=0.10, which is not installed.
#   cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 66.1.1 which is incompatible.
#   Successfully installed setuptools-66.1.1
#   Installing build dependencies ... done
#   Running command Getting requirements to build wheel
#   Getting requirements to build wheel ... done
#   Running command pip subprocess to install backend dependencies
#   Using pip 22.0.4 from /tmp/pip-standalone-pip-omgsvdez/__env_pip__.zip/pip (python 3.8)
#   Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://us-python.pkg.dev/colab-wheels/public/simple/
#   Collecting wheel
#     Downloading wheel-0.38.4-py3-none-any.whl (36 kB)
#   Installing collected packages: wheel
#     Creating /tmp/pip-build-env-4rav1mnl/normal/bin
#     changing mode of /tmp/pip-build-env-4rav1mnl/normal/bin/wheel to 755
#   Successfully installed wheel-0.38.4
#   Installing backend dependencies ... done
#   Running command Preparing metadata (pyproject.toml)
#   running dist_info
#   creating /tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info
#   writing /tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/SOURCES.txt'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-modern-metadata-fd9xrov2/mani_skill2.egg-info/SOURCES.txt'
#   creating '/tmp/pip-modern-metadata-fd9xrov2/mani_skill2-0.3.0.dist-info'
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: imageio[ffmpeg] in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (2.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (6.0)
# Collecting rtree
#   Downloading Rtree-1.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (4.6.0.66)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (3.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (0.8.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from mani-skill2==0.3.0) (1.7.3)
# Collecting GitPython
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 21.4 MB/s eta 0:00:00
# Collecting trimesh
#   Downloading trimesh-3.18.1-py3-none-any.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.9/670.9 KB 49.1 MB/s eta 0:00:00
# Collecting sapien==2.1.0
#   Downloading sapien-2.1.0-cp38-cp38-manylinux2014_x86_64.whl (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 63.9 MB/s eta 0:00:00
# Collecting transforms3d
#   Downloading transforms3d-0.4.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.2 MB/s eta 0:00:00
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info
#   writing /tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   adding license file 'AUTHORS'
#   writing manifest file '/tmp/pip-pip-egg-info-v4aj0k37/transforms3d.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting gym<=0.21.0,>=0.18.3
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.6 MB/s eta 0:00:00
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info
#   writing /tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-chh7p_2p/gym.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.8/dist-packages (from sapien==2.1.0->mani-skill2==0.3.0) (2.25.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym<=0.21.0,>=0.18.3->mani-skill2==0.3.0) (2.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from imageio[ffmpeg]->mani-skill2==0.3.0) (7.1.2)
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 44.6 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.1.0->mani-skill2==0.3.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.1.0->mani-skill2==0.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.1.0->mani-skill2==0.3.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.1.0->mani-skill2==0.3.0) (1.24.3)
# Building wheels for collected packages: mani-skill2, gym, transforms3d
#   Running command git rev-parse HEAD
#   f217f9ae920bafbf3d17f800141db0eaba0251c6
#   Running command Building wheel for mani-skill2 (pyproject.toml)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/mani_skill2
#   copying mani_skill2/__init__.py -> build/lib/mani_skill2
#   creating build/lib/warp_maniskill
#   copying warp_maniskill/build_exports.py -> build/lib/warp_maniskill
#   copying warp_maniskill/setup.py -> build/lib/warp_maniskill
#   copying warp_maniskill/build_lib.py -> build/lib/warp_maniskill
#   copying warp_maniskill/build_docs.py -> build/lib/warp_maniskill
#   copying warp_maniskill/__init__.py -> build/lib/warp_maniskill
#   creating build/lib/mani_skill2/trajectory
#   copying mani_skill2/trajectory/merge_trajectory.py -> build/lib/mani_skill2/trajectory
#   copying mani_skill2/trajectory/replay_trajectory.py -> build/lib/mani_skill2/trajectory
#   copying mani_skill2/trajectory/__init__.py -> build/lib/mani_skill2/trajectory
#   creating build/lib/mani_skill2/envs
#   copying mani_skill2/envs/__init__.py -> build/lib/mani_skill2/envs
#   copying mani_skill2/envs/sapien_env.py -> build/lib/mani_skill2/envs
#   creating build/lib/mani_skill2/sensors
#   copying mani_skill2/sensors/camera.py -> build/lib/mani_skill2/sensors
#   copying mani_skill2/sensors/__init__.py -> build/lib/mani_skill2/sensors
#   creating build/lib/mani_skill2/agents
#   copying mani_skill2/agents/base_agent.py -> build/lib/mani_skill2/agents
#   copying mani_skill2/agents/__init__.py -> build/lib/mani_skill2/agents
#   copying mani_skill2/agents/base_controller.py -> build/lib/mani_skill2/agents
#   copying mani_skill2/agents/utils.py -> build/lib/mani_skill2/agents
#   creating build/lib/mani_skill2/utils
#   copying mani_skill2/utils/registration.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/download_asset.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/trimesh_utils.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/logging_utils.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/geometry.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/sapien_utils.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/download_demo.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/bounding_cylinder.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/__init__.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/io_utils.py -> build/lib/mani_skill2/utils
#   copying mani_skill2/utils/common.py -> build/lib/mani_skill2/utils
#   creating build/lib/mani_skill2/vector
#   copying mani_skill2/vector/vec_env.py -> build/lib/mani_skill2/vector
#   copying mani_skill2/vector/__init__.py -> build/lib/mani_skill2/vector
#   creating build/lib/mani_skill2/evaluation
#   copying mani_skill2/evaluation/solution.py -> build/lib/mani_skill2/evaluation
#   copying mani_skill2/evaluation/run_evaluation.py -> build/lib/mani_skill2/evaluation
#   copying mani_skill2/evaluation/evaluator.py -> build/lib/mani_skill2/evaluation
#   copying mani_skill2/evaluation/__init__.py -> build/lib/mani_skill2/evaluation
#   creating build/lib/mani_skill2/envs/misc
#   copying mani_skill2/envs/misc/avoid_obstacles.py -> build/lib/mani_skill2/envs/misc
#   copying mani_skill2/envs/misc/__init__.py -> build/lib/mani_skill2/envs/misc
#   copying mani_skill2/envs/misc/turn_faucet.py -> build/lib/mani_skill2/envs/misc
#   creating build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/write_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/hang_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/excavate_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/pinch_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/pour_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/base_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/__init__.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/utils.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/fill_env.py -> build/lib/mani_skill2/envs/mpm
#   copying mani_skill2/envs/mpm/perlin.py -> build/lib/mani_skill2/envs/mpm
#   creating build/lib/mani_skill2/envs/ms1
#   copying mani_skill2/envs/ms1/move_bucket.py -> build/lib/mani_skill2/envs/ms1
#   copying mani_skill2/envs/ms1/open_cabinet_door_drawer.py -> build/lib/mani_skill2/envs/ms1
#   copying mani_skill2/envs/ms1/base_env.py -> build/lib/mani_skill2/envs/ms1
#   copying mani_skill2/envs/ms1/__init__.py -> build/lib/mani_skill2/envs/ms1
#   copying mani_skill2/envs/ms1/push_chair.py -> build/lib/mani_skill2/envs/ms1
#   creating build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/pick_single.py -> build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/base_env.py -> build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/__init__.py -> build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/pick_clutter.py -> build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/stack_cube.py -> build/lib/mani_skill2/envs/pick_and_place
#   copying mani_skill2/envs/pick_and_place/pick_cube.py -> build/lib/mani_skill2/envs/pick_and_place
#   creating build/lib/mani_skill2/envs/assembly
#   copying mani_skill2/envs/assembly/plug_charger.py -> build/lib/mani_skill2/envs/assembly
#   copying mani_skill2/envs/assembly/assembling_kits.py -> build/lib/mani_skill2/envs/assembly
#   copying mani_skill2/envs/assembly/base_env.py -> build/lib/mani_skill2/envs/assembly
#   copying mani_skill2/envs/assembly/__init__.py -> build/lib/mani_skill2/envs/assembly
#   copying mani_skill2/envs/assembly/peg_insertion_side.py -> build/lib/mani_skill2/envs/assembly
#   creating build/lib/mani_skill2/agents/robots
#   copying mani_skill2/agents/robots/panda.py -> build/lib/mani_skill2/agents/robots
#   copying mani_skill2/agents/robots/xmate3.py -> build/lib/mani_skill2/agents/robots
#   copying mani_skill2/agents/robots/mobile_panda.py -> build/lib/mani_skill2/agents/robots
#   copying mani_skill2/agents/robots/__init__.py -> build/lib/mani_skill2/agents/robots
#   creating build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/passive_controller.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/pd_joint_pos_vel.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/pd_base_vel.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/pd_joint_vel.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/__init__.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/pd_joint_pos.py -> build/lib/mani_skill2/agents/controllers
#   copying mani_skill2/agents/controllers/pd_ee_pose.py -> build/lib/mani_skill2/agents/controllers
#   creating build/lib/mani_skill2/agents/configs
#   copying mani_skill2/agents/configs/__init__.py -> build/lib/mani_skill2/agents/configs
#   creating build/lib/mani_skill2/agents/configs/mobile_panda
#   copying mani_skill2/agents/configs/mobile_panda/defaults.py -> build/lib/mani_skill2/agents/configs/mobile_panda
#   copying mani_skill2/agents/configs/mobile_panda/__init__.py -> build/lib/mani_skill2/agents/configs/mobile_panda
#   creating build/lib/mani_skill2/agents/configs/panda
#   copying mani_skill2/agents/configs/panda/defaults.py -> build/lib/mani_skill2/agents/configs/panda
#   copying mani_skill2/agents/configs/panda/variants.py -> build/lib/mani_skill2/agents/configs/panda
#   copying mani_skill2/agents/configs/panda/__init__.py -> build/lib/mani_skill2/agents/configs/panda
#   creating build/lib/mani_skill2/agents/configs/xmate3
#   copying mani_skill2/agents/configs/xmate3/defaults.py -> build/lib/mani_skill2/agents/configs/xmate3
#   copying mani_skill2/agents/configs/xmate3/__init__.py -> build/lib/mani_skill2/agents/configs/xmate3
#   creating build/lib/mani_skill2/utils/wrappers
#   copying mani_skill2/utils/wrappers/record.py -> build/lib/mani_skill2/utils/wrappers
#   copying mani_skill2/utils/wrappers/observation.py -> build/lib/mani_skill2/utils/wrappers
#   copying mani_skill2/utils/wrappers/__init__.py -> build/lib/mani_skill2/utils/wrappers
#   copying mani_skill2/utils/wrappers/common.py -> build/lib/mani_skill2/utils/wrappers
#   creating build/lib/mani_skill2/utils/visualization
#   copying mani_skill2/utils/visualization/jupyter_utils.py -> build/lib/mani_skill2/utils/visualization
#   copying mani_skill2/utils/visualization/cv2_utils.py -> build/lib/mani_skill2/utils/visualization
#   copying mani_skill2/utils/visualization/misc.py -> build/lib/mani_skill2/utils/visualization
#   copying mani_skill2/utils/visualization/__init__.py -> build/lib/mani_skill2/utils/visualization
#   creating build/lib/mani_skill2/vector/wrappers
#   copying mani_skill2/vector/wrappers/observation.py -> build/lib/mani_skill2/vector/wrappers
#   copying mani_skill2/vector/wrappers/sb3.py -> build/lib/mani_skill2/vector/wrappers
#   copying mani_skill2/vector/wrappers/__init__.py -> build/lib/mani_skill2/vector/wrappers
#   creating build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/codegen.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/distance.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/types.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/stubs.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/config.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/torch.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/__init__.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/context.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/render.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/tape.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/builtins.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/build.py -> build/lib/warp_maniskill/warp
#   copying warp_maniskill/warp/utils.py -> build/lib/warp_maniskill/warp
#   creating build/lib/warp_maniskill/mpm
#   copying warp_maniskill/mpm/mpm_model.py -> build/lib/warp_maniskill/mpm
#   copying warp_maniskill/mpm/mpm_simulator.py -> build/lib/warp_maniskill/mpm
#   copying warp_maniskill/mpm/height_rasterizer.py -> build/lib/warp_maniskill/mpm
#   copying warp_maniskill/mpm/__init__.py -> build/lib/warp_maniskill/mpm
#   copying warp_maniskill/mpm/mpm_integrator.py -> build/lib/warp_maniskill/mpm
#   creating build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/import_snu.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/integrator_euler.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/integrator_xpbd.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/collide.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/__init__.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/optimizer.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/render.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/articulation.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/import_urdf.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/particles.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/import_mjcf.py -> build/lib/warp_maniskill/warp/sim
#   copying warp_maniskill/warp/sim/model.py -> build/lib/warp_maniskill/warp/sim
#   creating build/lib/warp_maniskill/warp/thirdparty
#   copying warp_maniskill/warp/thirdparty/__init__.py -> build/lib/warp_maniskill/warp/thirdparty
#   copying warp_maniskill/warp/thirdparty/appdirs.py -> build/lib/warp_maniskill/warp/thirdparty
#   creating build/lib/mani_skill2/assets
#   creating build/lib/mani_skill2/assets/partnet_mobility
#   creating build/lib/mani_skill2/assets/partnet_mobility/meta
#   copying mani_skill2/assets/partnet_mobility/meta/info_cabinet_drawer_train.json -> build/lib/mani_skill2/assets/partnet_mobility/meta
#   copying mani_skill2/assets/partnet_mobility/meta/info_bucket_train.json -> build/lib/mani_skill2/assets/partnet_mobility/meta
#   copying mani_skill2/assets/partnet_mobility/meta/info_chair_train.json -> build/lib/mani_skill2/assets/partnet_mobility/meta
#   copying mani_skill2/assets/partnet_mobility/meta/info_faucet_train.json -> build/lib/mani_skill2/assets/partnet_mobility/meta
#   copying mani_skill2/assets/partnet_mobility/meta/info_cabinet_door_train.json -> build/lib/mani_skill2/assets/partnet_mobility/meta
#   creating build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_bucket.srdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_v2.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_v3.srdf -> build/lib/mani_skill2/assets/descriptions
#   creating build/lib/mani_skill2/assets/descriptions/bucket
#   copying mani_skill2/assets/descriptions/bucket/bucket.stl -> build/lib/mani_skill2/assets/descriptions/bucket
#   copying mani_skill2/assets/descriptions/bucket/bucket_45.stl -> build/lib/mani_skill2/assets/descriptions/bucket
#   copying mani_skill2/assets/descriptions/panda_bucket.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_stick.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/mobile_panda_single_arm.urdf -> build/lib/mani_skill2/assets/descriptions
#   creating build/lib/mani_skill2/assets/descriptions/franka_description
#   creating build/lib/mani_skill2/assets/descriptions/franka_description/meshes
#   creating build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link5.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link4.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/hand.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link3.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link6.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link0.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/finger.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link7.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link2.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   copying mani_skill2/assets/descriptions/franka_description/meshes/visual/link1.dae -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/visual
#   creating build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link0.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/hand.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link5.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link1.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/finger.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link4.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link6.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link2.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link7.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/franka_description/meshes/collision/link3.stl -> build/lib/mani_skill2/assets/descriptions/franka_description/meshes/collision
#   copying mani_skill2/assets/descriptions/panda_v2.srdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_v2_gripper.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_v3.urdf -> build/lib/mani_skill2/assets/descriptions
#   creating build/lib/mani_skill2/assets/descriptions/sciurus17_description
#   creating build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes
#   creating build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/visual
#   copying mani_skill2/assets/descriptions/sciurus17_description/meshes/visual/Base.stl -> build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/visual
#   copying mani_skill2/assets/descriptions/sciurus17_description/meshes/visual/Body.stl -> build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/visual
#   creating build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/collision
#   copying mani_skill2/assets/descriptions/sciurus17_description/meshes/collision/Base.stl -> build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/collision
#   copying mani_skill2/assets/descriptions/sciurus17_description/meshes/collision/Body.stl -> build/lib/mani_skill2/assets/descriptions/sciurus17_description/meshes/collision
#   copying mani_skill2/assets/descriptions/panda_pinch.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_stick.srdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/mobile_panda_dual_arm.urdf -> build/lib/mani_skill2/assets/descriptions
#   copying mani_skill2/assets/descriptions/panda_pinch.srdf -> build/lib/mani_skill2/assets/descriptions
#   creating build/lib/mani_skill2/assets/deformable_manipulation
#   copying mani_skill2/assets/deformable_manipulation/beaker.glb -> build/lib/mani_skill2/assets/deformable_manipulation
#   copying mani_skill2/assets/deformable_manipulation/bottle.glb -> build/lib/mani_skill2/assets/deformable_manipulation
#   copying mani_skill2/assets/maniskill2-scene-2.glb -> build/lib/mani_skill2/assets
#   creating build/lib/mani_skill2/envs/mpm/shader
#   creating build/lib/mani_skill2/envs/mpm/shader/common
#   copying mani_skill2/envs/mpm/shader/common/view.glsl -> build/lib/mani_skill2/envs/mpm/shader/common
#   copying mani_skill2/envs/mpm/shader/common/lights.glsl -> build/lib/mani_skill2/envs/mpm/shader/common
#   copying mani_skill2/envs/mpm/shader/common/shadow.glsl -> build/lib/mani_skill2/envs/mpm/shader/common
#   creating build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer2.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/point.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/line.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/shadow_point.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/deferred.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/shadow.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer1.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/point.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer1.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/shadow_point.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/line.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/deferred.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/gbuffer2.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/composite1.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/composite.vert -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/composite0.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   copying mani_skill2/envs/mpm/shader/point/composite2.frag -> build/lib/mani_skill2/envs/mpm/shader/point
#   creating build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mesh.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/marching.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/bvh.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/sort.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/matnn.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/crt.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mat44.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/vec3.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/hashgrid.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/hashgrid.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/intersect_tri.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/dense_volume.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/rand.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mat33.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/volume.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/exports.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/range.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mesh.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/marching.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/quat.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/warp.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/svd.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/warp.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/intersect.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/dense_volume.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/builtin.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/noise.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/vec2.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/warp.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mat22.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/sort.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/mesh.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/intersect_adj.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/sort.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/volume.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/bvh.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/vec4.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/array.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/spatial.h -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/hashgrid.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/dense_volume.cu -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/marching.cpp -> build/lib/warp_maniskill/warp/native
#   copying warp_maniskill/warp/native/bvh.h -> build/lib/warp_maniskill/warp/native
#   creating build/lib/warp_maniskill/warp/native/nanovdb
#   copying warp_maniskill/warp/native/nanovdb/PNanoVDB.h -> build/lib/warp_maniskill/warp/native/nanovdb
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/mani_skill2
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/trajectory
#   copying build/lib/mani_skill2/trajectory/merge_trajectory.py -> build/bdist.linux-x86_64/wheel/mani_skill2/trajectory
#   copying build/lib/mani_skill2/trajectory/replay_trajectory.py -> build/bdist.linux-x86_64/wheel/mani_skill2/trajectory
#   copying build/lib/mani_skill2/trajectory/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/trajectory
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/misc
#   copying build/lib/mani_skill2/envs/misc/avoid_obstacles.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/misc
#   copying build/lib/mani_skill2/envs/misc/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/misc
#   copying build/lib/mani_skill2/envs/misc/turn_faucet.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/misc
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/write_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/hang_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/common
#   copying build/lib/mani_skill2/envs/mpm/shader/common/view.glsl -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/common
#   copying build/lib/mani_skill2/envs/mpm/shader/common/lights.glsl -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/common
#   copying build/lib/mani_skill2/envs/mpm/shader/common/shadow.glsl -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/common
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer2.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/point.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/line.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/shadow_point.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/deferred.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/shadow.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer1.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/point.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer1.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/shadow_point.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/line.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/deferred.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/gbuffer2.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/composite1.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/composite.vert -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/composite0.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/shader/point/composite2.frag -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm/shader/point
#   copying build/lib/mani_skill2/envs/mpm/excavate_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/pinch_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/pour_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/base_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/utils.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/fill_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   copying build/lib/mani_skill2/envs/mpm/perlin.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/mpm
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   copying build/lib/mani_skill2/envs/ms1/move_bucket.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   copying build/lib/mani_skill2/envs/ms1/open_cabinet_door_drawer.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   copying build/lib/mani_skill2/envs/ms1/base_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   copying build/lib/mani_skill2/envs/ms1/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   copying build/lib/mani_skill2/envs/ms1/push_chair.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/ms1
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/pick_single.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/base_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/pick_clutter.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/stack_cube.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/pick_and_place/pick_cube.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/pick_and_place
#   copying build/lib/mani_skill2/envs/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/assembly/plug_charger.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/assembly/assembling_kits.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/assembly/base_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/assembly/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/assembly/peg_insertion_side.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs/assembly
#   copying build/lib/mani_skill2/envs/sapien_env.py -> build/bdist.linux-x86_64/wheel/mani_skill2/envs
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/sensors
#   copying build/lib/mani_skill2/sensors/camera.py -> build/bdist.linux-x86_64/wheel/mani_skill2/sensors
#   copying build/lib/mani_skill2/sensors/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/sensors
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/agents
#   copying build/lib/mani_skill2/agents/base_agent.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/agents/robots
#   copying build/lib/mani_skill2/agents/robots/panda.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents/robots
#   copying build/lib/mani_skill2/agents/robots/xmate3.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents/robots
#   copying build/lib/mani_skill2/agents/robots/mobile_panda.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents/robots
#   copying build/lib/mani_skill2/agents/robots/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents/robots
#   copying build/lib/mani_skill2/agents/__init__.py -> build/bdist.linux-x86_64/wheel/mani_skill2/agents
#   creating build/bdist.linux-x86_64/wheel/mani_skill2/agents/controllers
# ...
#   adding 'gym/envs/robotics/assets/stls/hand/palm.stl'
#   adding 'gym/envs/robotics/assets/stls/hand/wrist.stl'
#   adding 'gym/envs/robotics/assets/textures/block.png'
#   adding 'gym/envs/robotics/assets/textures/block_hidden.png'
#   adding 'gym/envs/robotics/fetch/__init__.py'
#   adding 'gym/envs/robotics/fetch/pick_and_place.py'
#   adding 'gym/envs/robotics/fetch/push.py'
#   adding 'gym/envs/robotics/fetch/reach.py'
#   adding 'gym/envs/robotics/fetch/slide.py'
#   adding 'gym/envs/robotics/hand/__init__.py'
#   adding 'gym/envs/robotics/hand/manipulate.py'
#   adding 'gym/envs/robotics/hand/manipulate_touch_sensors.py'
#   adding 'gym/envs/robotics/hand/reach.py'
#   adding 'gym/envs/toy_text/__init__.py'
#   adding 'gym/envs/toy_text/blackjack.py'
#   adding 'gym/envs/toy_text/cliffwalking.py'
#   adding 'gym/envs/toy_text/discrete.py'
#   adding 'gym/envs/toy_text/frozen_lake.py'
#   adding 'gym/envs/toy_text/taxi.py'
#   adding 'gym/envs/unittest/__init__.py'
#   adding 'gym/envs/unittest/cube_crash.py'
#   adding 'gym/envs/unittest/memorize_digits.py'
#   adding 'gym/spaces/__init__.py'
#   adding 'gym/spaces/box.py'
#   adding 'gym/spaces/dict.py'
#   adding 'gym/spaces/discrete.py'
#   adding 'gym/spaces/multi_binary.py'
#   adding 'gym/spaces/multi_discrete.py'
#   adding 'gym/spaces/space.py'
#   adding 'gym/spaces/tuple.py'
#   adding 'gym/spaces/utils.py'
#   adding 'gym/utils/__init__.py'
#   adding 'gym/utils/atomic_write.py'
#   adding 'gym/utils/closer.py'
#   adding 'gym/utils/colorize.py'
#   adding 'gym/utils/env_checker.py'
#   adding 'gym/utils/ezpickle.py'
#   adding 'gym/utils/json_utils.py'
#   adding 'gym/utils/play.py'
#   adding 'gym/utils/seeding.py'
#   adding 'gym/vector/__init__.py'
#   adding 'gym/vector/async_vector_env.py'
#   adding 'gym/vector/sync_vector_env.py'
#   adding 'gym/vector/vector_env.py'
#   adding 'gym/vector/utils/__init__.py'
#   adding 'gym/vector/utils/misc.py'
#   adding 'gym/vector/utils/numpy_utils.py'
#   adding 'gym/vector/utils/shared_memory.py'
#   adding 'gym/vector/utils/spaces.py'
#   adding 'gym/wrappers/__init__.py'
#   adding 'gym/wrappers/atari_preprocessing.py'
#   adding 'gym/wrappers/clip_action.py'
#   adding 'gym/wrappers/filter_observation.py'
#   adding 'gym/wrappers/flatten_observation.py'
#   adding 'gym/wrappers/frame_stack.py'
#   adding 'gym/wrappers/gray_scale_observation.py'
#   adding 'gym/wrappers/monitor.py'
#   adding 'gym/wrappers/normalize.py'
#   adding 'gym/wrappers/order_enforcing.py'
#   adding 'gym/wrappers/pixel_observation.py'
#   adding 'gym/wrappers/record_episode_statistics.py'
#   adding 'gym/wrappers/record_video.py'
#   adding 'gym/wrappers/rescale_action.py'
#   adding 'gym/wrappers/resize_observation.py'
#   adding 'gym/wrappers/time_aware_observation.py'
#   adding 'gym/wrappers/time_limit.py'
#   adding 'gym/wrappers/transform_observation.py'
#   adding 'gym/wrappers/transform_reward.py'
#   adding 'gym/wrappers/monitoring/__init__.py'
#   adding 'gym/wrappers/monitoring/stats_recorder.py'
#   adding 'gym/wrappers/monitoring/video_recorder.py'
#   adding 'gym-0.21.0.dist-info/METADATA'
#   adding 'gym-0.21.0.dist-info/WHEEL'
#   adding 'gym-0.21.0.dist-info/top_level.txt'
#   adding 'gym-0.21.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616796 sha256=859e401e542d8be2aa767fe6b31771aca2191ceae2dbda4644ae0db1c19ec24c
#   Stored in directory: /root/.cache/pip/wheels/27/6d/b3/a3a6e10704795c9b9000f1ab2dc480dfe7bed42f5972806e73
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/transforms3d
#   copying transforms3d/shears.py -> build/lib/transforms3d
#   copying transforms3d/reflections.py -> build/lib/transforms3d
#   copying transforms3d/quaternions.py -> build/lib/transforms3d
#   copying transforms3d/_version.py -> build/lib/transforms3d
#   copying transforms3d/_gohlketransforms.py -> build/lib/transforms3d
#   copying transforms3d/euler.py -> build/lib/transforms3d
#   copying transforms3d/conftest.py -> build/lib/transforms3d
#   copying transforms3d/__init__.py -> build/lib/transforms3d
#   copying transforms3d/axangles.py -> build/lib/transforms3d
#   copying transforms3d/affines.py -> build/lib/transforms3d
#   copying transforms3d/testing.py -> build/lib/transforms3d
#   copying transforms3d/zooms.py -> build/lib/transforms3d
#   copying transforms3d/taitbryan.py -> build/lib/transforms3d
#   copying transforms3d/utils.py -> build/lib/transforms3d
#   creating build/lib/transforms3d/derivations
#   copying transforms3d/derivations/quaternions.py -> build/lib/transforms3d/derivations
#   copying transforms3d/derivations/eulerangles.py -> build/lib/transforms3d/derivations
#   copying transforms3d/derivations/__init__.py -> build/lib/transforms3d/derivations
#   copying transforms3d/derivations/angle_axes.py -> build/lib/transforms3d/derivations
#   copying transforms3d/derivations/decompositions.py -> build/lib/transforms3d/derivations
#   copying transforms3d/derivations/utils.py -> build/lib/transforms3d/derivations
#   creating build/lib/transforms3d/tests
#   copying transforms3d/tests/test_quaternions.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_axangles.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_utils.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/samples.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_zooms_shears.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_reflections.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/__init__.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_affines.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_taitbryan.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_implementations.py -> build/lib/transforms3d/tests
#   copying transforms3d/tests/test_euler.py -> build/lib/transforms3d/tests
#   creating build/lib/transforms3d/tests/data
#   copying transforms3d/tests/data/processed_quats.mat -> build/lib/transforms3d/tests/data
#   copying transforms3d/tests/data/process_quats.m -> build/lib/transforms3d/tests/data
#   UPDATING build/lib/transforms3d/_version.py
#   set build/lib/transforms3d/_version.py to '0.4.1'
#   /usr/local/lib/python3.8/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/shears.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/reflections.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/quaternions.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/_version.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/_gohlketransforms.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   creating build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_quaternions.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_axangles.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_utils.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   creating build/bdist.linux-x86_64/wheel/transforms3d/tests/data
#   copying build/lib/transforms3d/tests/data/processed_quats.mat -> build/bdist.linux-x86_64/wheel/transforms3d/tests/data
#   copying build/lib/transforms3d/tests/data/process_quats.m -> build/bdist.linux-x86_64/wheel/transforms3d/tests/data
#   copying build/lib/transforms3d/tests/samples.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_zooms_shears.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_reflections.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/__init__.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_affines.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_taitbryan.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_implementations.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/tests/test_euler.py -> build/bdist.linux-x86_64/wheel/transforms3d/tests
#   copying build/lib/transforms3d/euler.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/conftest.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/__init__.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/axangles.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/affines.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/testing.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/zooms.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   copying build/lib/transforms3d/taitbryan.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   creating build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/quaternions.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/eulerangles.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/__init__.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/angle_axes.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/decompositions.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/derivations/utils.py -> build/bdist.linux-x86_64/wheel/transforms3d/derivations
#   copying build/lib/transforms3d/utils.py -> build/bdist.linux-x86_64/wheel/transforms3d
#   running install_egg_info
#   running egg_info
#   writing transforms3d.egg-info/PKG-INFO
#   writing dependency_links to transforms3d.egg-info/dependency_links.txt
#   writing top-level names to transforms3d.egg-info/top_level.txt
#   reading manifest file 'transforms3d.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   adding license file 'LICENSE'
#   adding license file 'AUTHORS'
#   writing manifest file 'transforms3d.egg-info/SOURCES.txt'
#   Copying transforms3d.egg-info to build/bdist.linux-x86_64/wheel/transforms3d-0.4.1-py3.8.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/transforms3d-0.4.1.dist-info/WHEEL
#   creating '/tmp/pip-wheel-0w6gvpar/transforms3d-0.4.1-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'transforms3d/__init__.py'
#   adding 'transforms3d/_gohlketransforms.py'
#   adding 'transforms3d/_version.py'
#   adding 'transforms3d/affines.py'
#   adding 'transforms3d/axangles.py'
#   adding 'transforms3d/conftest.py'
#   adding 'transforms3d/euler.py'
#   adding 'transforms3d/quaternions.py'
#   adding 'transforms3d/reflections.py'
#   adding 'transforms3d/shears.py'
#   adding 'transforms3d/taitbryan.py'
#   adding 'transforms3d/testing.py'
#   adding 'transforms3d/utils.py'
#   adding 'transforms3d/zooms.py'
#   adding 'transforms3d/derivations/__init__.py'
#   adding 'transforms3d/derivations/angle_axes.py'
#   adding 'transforms3d/derivations/decompositions.py'
#   adding 'transforms3d/derivations/eulerangles.py'
#   adding 'transforms3d/derivations/quaternions.py'
#   adding 'transforms3d/derivations/utils.py'
#   adding 'transforms3d/tests/__init__.py'
#   adding 'transforms3d/tests/samples.py'
#   adding 'transforms3d/tests/test_affines.py'
#   adding 'transforms3d/tests/test_axangles.py'
#   adding 'transforms3d/tests/test_euler.py'
#   adding 'transforms3d/tests/test_implementations.py'
#   adding 'transforms3d/tests/test_quaternions.py'
#   adding 'transforms3d/tests/test_reflections.py'
#   adding 'transforms3d/tests/test_taitbryan.py'
#   adding 'transforms3d/tests/test_utils.py'
#   adding 'transforms3d/tests/test_zooms_shears.py'
#   adding 'transforms3d/tests/data/process_quats.m'
#   adding 'transforms3d/tests/data/processed_quats.mat'
#   adding 'transforms3d-0.4.1.dist-info/AUTHORS'
#   adding 'transforms3d-0.4.1.dist-info/LICENSE'
#   adding 'transforms3d-0.4.1.dist-info/METADATA'
#   adding 'transforms3d-0.4.1.dist-info/WHEEL'
#   adding 'transforms3d-0.4.1.dist-info/top_level.txt'
#   adding 'transforms3d-0.4.1.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.4.1-py3-none-any.whl size=1376757 sha256=e267d81351223c2b16091d93c36f381c484452c70ab0b54ff9575c29164cbbbf
#   Stored in directory: /root/.cache/pip/wheels/7b/f0/88/0198ac6eca77ffa36e7247595585e9ec34e1dcc327847ebe73
# Successfully built mani-skill2 gym transforms3d
# Installing collected packages: trimesh, transforms3d, smmap, rtree, imageio-ffmpeg, gym, sapien, gitdb, GitPython, mani-skill2
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Removing file or directory /usr/local/lib/python3.8/dist-packages/gym-0.25.2.dist-info/
#       Removing file or directory /usr/local/lib/python3.8/dist-packages/gym/
#       Successfully uninstalled gym-0.25.2
#   Running command git rev-parse HEAD
#   f217f9ae920bafbf3d17f800141db0eaba0251c6
# Successfully installed GitPython-3.1.30 gitdb-4.0.10 gym-0.21.0 imageio-ffmpeg-0.4.8 mani-skill2-0.3.0 rtree-1.0.1 sapien-2.1.0 smmap-5.0.0 transforms3d-0.4.1 trimesh-3.18.1
# Found existing installation: pathlib 1.0.1
# Uninstalling pathlib-1.0.1:
#   Successfully uninstalled pathlib-1.0.1
# Found existing installation: sapien 2.1.0
# Uninstalling sapien-2.1.0:
#   Successfully uninstalled sapien-2.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sapien==2.0.0.dev20230112
#   Downloading https://anaconda.org/jigu/sapien/2.0.0.dev20230112/download/sapien-2.0.0.dev20230112-cp38-cp38-manylinux2014_x86_64.whl (32.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.4/32.4 MB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: transforms3d>=0.3 in /usr/local/lib/python3.8/dist-packages (from sapien==2.0.0.dev20230112) (0.4.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from sapien==2.0.0.dev20230112) (1.21.6)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.8/dist-packages (from sapien==2.0.0.dev20230112) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.0.0.dev20230112) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.0.0.dev20230112) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.0.0.dev20230112) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22->sapien==2.0.0.dev20230112) (1.24.3)
# Installing collected packages: sapien
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mani-skill2 0.3.0 requires sapien==2.1.0, but you have sapien 2.0.0.dev20230112 which is incompatible.
# Successfully installed sapien-2.0.0.dev20230112
# /bin/bash: line 0: cd: ManiSkill2: No such file or directory

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    import site
    site.main() # run this so local pip installs are recognized

# %% [markdown]
# # HW 1 Starter Code
#
# This starter code is the same as seen in `util.py` and `robot.py`. The code below is copied from `util.py` so make sure to run it

# %%
### util.py ###
import numpy as np
import time

def check_joint_limit(limits, types, q):
    # check whether the joint positions are within the joint limits
    n = len(q)
    for i in range(n):
        if types[i] == "revolute":
            # for revolute joints, q and q + 2k\pi are equivalent
            if (np.abs(q[i] - limits[i][0]) < 1e-3):
                continue
            q[i] -= 2 * np.pi * np.floor((q[i] - limits[i][0]) / (2 * np.pi))
            if q[i] > limits[i][1] + 1e-3:
                return False
        else:
            if q[i] < limits[i][0] - 1e-3 or q[i] > limits[i][1] + 1e-3:
                return False
    return True

def random_sample_qpos(limits):
    # randomly sample a joint position within the joint limits
    return np.random.rand(limits.shape[0]) * (limits[:, 1] - limits[:, 0]) + limits[:, 0]

def test_FK(robot, qpos):
    # take a set of joint positions as input
    # output the poses of all the links in that configuration
    print("FK Test with qpos: ", qpos, ".")
    robot.set_qpos(qpos)
    for link in robot.get_links():
        print("Link %s's pose is: " % link.get_name(), link.get_pose(), ".")
    print("----------------------------------------")

def test_jacobian(robot, qpos):
    # take a set of joint positions as input
    # output the corresponding Jacobian matrix
    print("Jacobian Test with qpos: ", qpos, ".")
    p_model = robot.create_pinocchio_model()
    p_model.compute_full_jacobian(qpos)
    for index, link in enumerate(robot.get_links()):
        if link.get_name() != "end_effector":
            continue
        print("Link %s" % link.get_name())
        print("Spatial Jacobian: ")
        print(p_model.get_link_jacobian(index, local=False))
        print("Body Jacobian: ")
        print(p_model.get_link_jacobian(index, local=True))
    print("----------------------------------------")

def distance_6D(p1, p2):
    # calculate the 6D distance between two sapien poses
    return np.linalg.norm(p1.p - p2.p) \
        + min(np.linalg.norm(p1.q - p2.q), np.linalg.norm(p1.q + p2.q))  # double covering

def test_IK(robot, method, trials=100, threshold=1e-3):
    # take a IK algorithm (function handle) as input
    # check the accuracy and runtime
    print("Test IK with %s" % method)
    ee_link = robot.get_links()[-3]
    joint_limits = np.concatenate([joint.get_limits() for joint in robot.get_active_joints()])
    joint_types = [joint.type for joint in robot.get_active_joints()]
    cnt = 0
    start = time.time()
    for _ in range(trials):
        q = random_sample_qpos(joint_limits)
        robot.set_qpos(q)
        goal_pose = ee_link.get_pose()
        _q = method(robot, goal_pose)
        if check_joint_limit(joint_limits, joint_types, _q):
            robot.set_qpos(_q)
            pred_pose = ee_link.get_pose()
            if distance_6D(goal_pose, pred_pose) < threshold:
                cnt += 1
    print("runtime: %f" % (time.time() - start))
    print("accuracy: %f" % (cnt / trials))
    print("----------------------------------------")

# %% [markdown]
# Fill in your answers below and run the code below to test your answer. It will generate an `output.png` file showing what your robot configuration looks like. To open the file and view it click the folder icon on the left of Colab and click `output.png`. If `output.png` doesn't show up try clicking the folder fresh icon.

# %%
### robot.py ###
import sapien.core as sapien
from sapien.utils import Viewer
import numpy as np
import transforms3d
#import sophus as sp

FILL_ME_P = [0., 0., 0.]
FILL_ME_Q = [1., 0., 0., 0.]

def create_robot(scene: sapien.Scene):
    # You can find a similar example at:
    # https://storage1.ucsd.edu/docs/sapien-dev/tutorial/basic/create_articulations.html
    builder = scene.create_articulation_builder()

    base: sapien.LinkBuilder = builder.create_link_builder()
    base.set_name('base')
    base.add_box_collision(half_size=[0.2, 0.2, 1.5])
    base.add_box_visual(half_size=[0.2, 0.2, 1.5], color=[0.4, 0.6, 0.8])

    link1 = builder.create_link_builder(base)
    link1.set_name('link1')
    link1.add_box_collision(half_size=[0.2, 1, 0.2])
    link1.add_box_visual(half_size=[0.2, 1, 0.2], color=[0.4, 0.8, 0.6])
    link1.set_joint_name('link1_joint')
    link1.set_joint_properties(
        "revolute", limits=[[-np.pi, np.pi]],
        # parent_pose refers to the relative linear transformation from the parent frame to the joint frame
        # in sapien, both revolute joint and prismatic joint points to the x-axis
        pose_in_parent=sapien.Pose(p=FILL_ME_P, # p is the position
                                q=FILL_ME_Q),  # q is the quaternion, you may use transforms3d 
        # child_pose refers to the relative linear transformation from the child frame to the joint frame
        pose_in_child=sapien.Pose(p=FILL_ME_P,
                                q=FILL_ME_Q)
    )

    link2 = builder.create_link_builder(link1)
    link2.set_name('link2')
    link2.add_box_collision(half_size=[0.2, 1, 0.2])
    link2.add_box_visual(half_size=[0.2, 1, 0.2], color=[0.6, 0.4, 0.8])
    link2.set_joint_name('link2_joint')
    link2.set_joint_properties(
        "revolute", limits=[[-np.pi / 2, np.pi / 2]],
        pose_in_parent=sapien.Pose(p=FILL_ME_P,
                                q=FILL_ME_Q),
        pose_in_child=sapien.Pose(p=FILL_ME_P,
                                q=FILL_ME_Q)
    )

    link3 = builder.create_link_builder(link2)
    link3.set_name('link3')
    link3.add_capsule_collision(radius=0.2, half_length=1, pose=sapien.Pose(q=FILL_ME_Q))
    link3.add_capsule_visual(radius=0.2, half_length=1, pose=sapien.Pose(q=FILL_ME_Q), color=[0.6, 0.8, 0.4])
    link3.set_joint_name('link3_joint')
    link3.set_joint_properties(
        "prismatic", limits=[[-1, 1]],
        pose_in_parent=sapien.Pose(p=FILL_ME_P,
                                q=FILL_ME_Q),
        pose_in_child=sapien.Pose(p=FILL_ME_P,
                                q=FILL_ME_Q)
    )

    end_effector = builder.create_link_builder(link3)
    end_effector.set_name('end_effector')
    end_effector.add_box_collision(half_size=[0.2, 0.5, 0.05])
    end_effector.add_box_visual(
        half_size=[0.2, 0.5, 0.05], color=[0.8, 0.4, 0.6])
    end_effector.set_joint_name('end_effctor_joint')
    end_effector.set_joint_properties(
        "fixed", limits=[],
        pose_in_parent=sapien.Pose(p=[0, 0, -1.2],
                                q=transforms3d.euler.euler2quat(0, 0, 0)),
        pose_in_child=sapien.Pose(p=[0, 0, 0.05],
                                q=transforms3d.euler.euler2quat(0, 0, 0))
    )

    # for simplicity, the gripper is fixed
    left_pad = builder.create_link_builder(end_effector)
    left_pad.set_name('left_pad')
    left_pad.add_box_collision(half_size=[0.2, 0.05, 0.4])
    left_pad.add_box_visual(half_size=[0.2, 0.05, 0.4], color=[0.8, 0.6, 0.4])
    left_pad.set_joint_name('left_pad_joint')
    left_pad.set_joint_properties(
        "fixed", limits=[],
        pose_in_parent=sapien.Pose(p=[0, -0.5, 0],
                                q=transforms3d.euler.euler2quat(0, 0, 0)),
        pose_in_child=sapien.Pose(p=[0, 0.05, 0.35],
                                q=transforms3d.euler.euler2quat(0, 0, 0))
    )

    right_pad = builder.create_link_builder(end_effector)
    right_pad.set_name('right_pad')
    right_pad.add_box_collision(half_size=[0.2, 0.05, 0.4])
    right_pad.add_box_visual(half_size=[0.2, 0.05, 0.4], color=[0.8, 0.6, 0.4])
    right_pad.set_joint_name('right_pad_joint')
    right_pad.set_joint_properties(
        "fixed", limits=[],
        pose_in_parent=sapien.Pose(p=[0, 0.5, 0],
                                q=transforms3d.euler.euler2quat(0, 0, 0)),
        pose_in_child=sapien.Pose(p=[0, -0.05, 0.35],
                                q=transforms3d.euler.euler2quat(0, 0, 0))
    )

    robot = builder.build(fix_root_link=True)
    robot.set_name('robot')
    robot.set_qpos([0, 0, 0]) # qpos indicates joint positions
    return robot


def IK_LMA(robot, goal_pose: sapien.Pose):
    # TODO: Please implement your IK_LMA algorithm (HW2)
    joint_limits = np.concatenate([joint.get_limits() for joint in robot.get_active_joints()])
    joint_types = [joint.type for joint in robot.get_active_joints()]
    q_init = random_sample_qpos(joint_limits) # intial theta
    ee_link = robot.get_links()[-3]
    p_model = robot.create_pinocchio_model()
    # you may use 'robot.set_qpos(q), ee_link.get_pose()' to get the link pose
    # you may use 'p_model.compute_full_jacobian(q), p_model.get_link_jacobian(ee_link.get_index(), local=False)' to get the spatial Jacobian
    # you may use sp.SE3.log() to calculate exponential coordinates
    return q


def IK_analytical(robot, goal_pose: sapien.Pose):
    # TODO: Please implement your analytical IK solution (HW2, optional)
    joint_limits = np.concatenate([joint.get_limits() for joint in robot.get_active_joints()])
    return random_sample_qpos(joint_limits)


def main():
    engine = sapien.Engine()
    renderer = sapien.VulkanRenderer()
    engine.set_renderer(renderer)

    scene_config = sapien.SceneConfig()
    scene_config.gravity = np.array([0.0, 0.0, 0.0])  # ignore the gravity
    scene = engine.create_scene(scene_config)
    scene.set_timestep(1 / 100.0)

    scene.add_ground(altitude=-1.5) # let base link frame align with world frame

    robot = create_robot(scene)
    print('The DoF of the robot is:', robot.dof)

    # HW1: You need to fill the blanks in `create_robot` and then run the following test cases
    # You can check your implementation with the first 4 test cases.
    test_FK(robot, [0, 0, 0])
    test_FK(robot, [0, 0, 0.7])
    test_FK(robot, [0, np.deg2rad(45), 0.7])
    test_FK(robot, [np.deg2rad(-30), np.deg2rad(45), 0.7])
    # Please report your output for this test case in your PDF submission
    #test_FK(robot, [np.deg2rad(95), np.deg2rad(-36), -0.3])

    # HW2: You can check your Jacobian solution with function `test_jacobian`
    #test_jacobian(robot, [np.deg2rad(45), np.deg2rad(-60), 0.7])

    # HW2: You need to implement `IK_LMA` and `IK_analytical` (optional)
    # then run the following test functions and report the outputs in your PDF submission
    #test_IK(robot, IK_LMA)
    #test_IK(robot, IK_analytical)

    scene.set_ambient_light([0.5, 0.5, 0.5])
    

    
    # uncomment the following codes and run with `xvfb-run python3 robot.py` if you do not no DISPLAY;
    # the result will be saved in `output.png`;
    # you may need tune the camera position for better visualization.
    from PIL import Image
    near, far = 0.1, 100
    width, height = 640, 480
    camera_mount_actor = scene.create_actor_builder().build_kinematic()
    camera = scene.add_mounted_camera(
        name="camera",
        actor=camera_mount_actor,
        pose=sapien.Pose(),  # relative to the mounted actor
        width=width,
        height=height,
        fovx=np.deg2rad(35),
        fovy=np.deg2rad(35),
        near=near,
        far=far,
    )

    print('Intrinsic matrix\n', camera.get_camera_matrix())

    # Compute the camera pose by specifying forward(x), left(y) and up(z)
    cam_pos = np.array([-2, -4, 3])
    forward = -cam_pos / np.linalg.norm(cam_pos)
    left = np.cross([0, 0, 1], forward)
    left = left / np.linalg.norm(left)
    up = np.cross(forward, left)
    mat44 = np.eye(4)
    mat44[:3, :3] = np.stack([forward, left, up], axis=1)
    mat44[:3, 3] = cam_pos
    camera_mount_actor.set_pose(sapien.Pose.from_transformation_matrix(mat44))

    scene.step()
    scene.update_render()

    camera.take_picture()
    #viewer.render()
    #continue
    rgba = camera.get_float_texture('Color')  # [H, W, 4]
    # An alias is also provided
    # rgba = camera.get_color_rgba()  # [H, W, 4]
    rgba_img = (rgba * 255).clip(0, 255).astype("uint8")
    rgba_pil = Image.fromarray(rgba_img)
    rgba_pil.save('output.png')
    return
main()
# Out:
# The DoF of the robot is: 3
# FK Test with qpos:  [0, 0, 0] .
# Link base's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link1's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link2's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link3's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link end_effector's pose is:  Pose([0, 0, -1.25], [1, 0, 0, 0]) .
# Link left_pad's pose is:  Pose([0, -0.55, -1.6], [1, 0, 0, 0]) .
# Link right_pad's pose is:  Pose([0, 0.55, -1.6], [1, 0, 0, 0]) .
# ----------------------------------------
# FK Test with qpos:  [0, 0, 0.7] .
# Link base's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link1's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link2's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link3's pose is:  Pose([0.7, 0, 0], [1, 0, 0, 0]) .
# Link end_effector's pose is:  Pose([0.7, 0, -1.25], [1, 0, 0, 0]) .
# Link left_pad's pose is:  Pose([0.7, -0.55, -1.6], [1, 0, 0, 0]) .
# Link right_pad's pose is:  Pose([0.7, 0.55, -1.6], [1, 0, 0, 0]) .
# ----------------------------------------
# FK Test with qpos:  [0, 0.7853981633974483, 0.7] .
# Link base's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link1's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link2's pose is:  Pose([0, 0, 0], [0.92388, 0.382683, 0, 0]) .
# Link link3's pose is:  Pose([0.7, 0, 0], [0.92388, 0.382683, 0, 0]) .
# Link end_effector's pose is:  Pose([0.7, 0.883884, -0.883883], [0.92388, 0.382683, 0, 0]) .
# Link left_pad's pose is:  Pose([0.7, 0.742462, -1.52028], [0.92388, 0.382683, 0, 0]) .
# Link right_pad's pose is:  Pose([0.7, 1.52028, -0.742462], [0.92388, 0.382683, 0, 0]) .
# ----------------------------------------
# FK Test with qpos:  [-0.5235987755982988, 0.7853981633974483, 0.7] .
# Link base's pose is:  Pose([0, 0, 0], [1, 0, 0, 0]) .
# Link link1's pose is:  Pose([0, 0, 0], [0.965926, -0.258819, 0, 0]) .
# Link link2's pose is:  Pose([0, 0, 0], [0.991445, 0.130526, 0, 0]) .
# Link link3's pose is:  Pose([0.7, 0, 0], [0.991445, 0.130526, 0, 0]) .
# Link end_effector's pose is:  Pose([0.7, 0.323524, -1.20741], [0.991445, 0.130526, 0, 0]) .
# Link left_pad's pose is:  Pose([0.7, -0.117148, -1.68783], [0.991445, 0.130526, 0, 0]) .
# Link right_pad's pose is:  Pose([0.7, 0.94537, -1.40313], [0.991445, 0.130526, 0, 0]) .
# ----------------------------------------
# Intrinsic matrix
#  [[761.18274   0.      320.        0.     ]
#  [  0.      761.18274 240.        0.     ]
#  [  0.        0.        1.        0.     ]
#  [  0.        0.        0.        1.     ]]
